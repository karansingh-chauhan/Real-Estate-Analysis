# %%
import pandas as pd
import numpy as np
import os

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
house_df=pd.read_csv("D:\\machine learning projecsts folders\\realstate\\houses.csv")
flat_df=pd.read_csv('D:\\machine learning projecsts folders\\realstate\\flats.csv')

# %%
train_df=pd.concat([house_df,flat_df],ignore_index=True)
