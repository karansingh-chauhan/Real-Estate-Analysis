# %%
import pandas as pd
import numpy as np
import os

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
house_df=pd.read_csv("D:\\machine learning projecsts folders\\realstate\\cleaned house data")
flat_df=pd.read_csv('D:\\machine learning projecsts folders\\realstate\\clean flat data')

# %%
train_df=pd.concat([house_df,flat_df],ignore_index=True)

# %%
train_df.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         House
# 1  5 Bedroom House for sale in Sector 21A Faridabad         House
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         House
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         House
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         House
#
#             society  price      rate    area                 areaWithType  \
# 0  bptp visionnaire   5.25   20115.0  2610.0  Plot area 290(242.48 sq.m.)
# 1               NaN   5.70  105751.0   539.0   Plot area 539(50.07 sq.m.)
# 2               NaN   2.10   38251.0   549.0       Plot area 61(51 sq.m.)
# 3               NaN   5.00   43066.0  1161.0  Plot area 129(107.86 sq.m.)
# 4               NaN   3.00   53763.0   558.0    Plot area 62(51.84 sq.m.)
#
#    bedRoom  bathroom balcony                      additionalRoom  \
# ...

# %%
train_df=train_df.sample(train_df.shape[0],ignore_index=True)

# %%
train_df.sample(6)
# Out:
#                                        property_name property_type  \
# 3202  4 Bedroom House for sale in Sector 109 Gurgaon         House
# 1678                 3 BHK Flat in Sector 77 Gurgaon          Flat
# 1446                 3 BHK Flat in Sector 92 Gurgaon          Flat
# 1571                 3 BHK Flat in Sector 65 Gurgaon          Flat
# 2124     5 Bedroom House for sale in Nirvana Country         House
# 893                  3 BHK Flat in Sector 69 Gurgaon          Flat
#
#                                   society  price     rate    area  \
# 3202  international city by sobha phase 2   6.25  11574.0  5400.0
# 1678                 emaar mgf palm hills   1.08   5400.0  2000.0
# 1446          bestech park view sanskruti   1.68  11052.0  1520.0
# 1571                       m3m golfestate   5.00  16666.0  3000.0
# 2124                       unitech espace    NaN      NaN     NaN
# 893                          tulip violet   1.55   9639.0  1608.0
#
# ...

# %%
train_df.to_csv("gurgaon.csv",index=False)
