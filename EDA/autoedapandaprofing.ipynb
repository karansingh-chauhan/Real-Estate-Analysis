# %%
import pandas as pd
# from pandas_profiling import ProfileReport

# %%
from ydata_profiling import ProfileReport


df = pd.read_csv('D:\\machine learning projecsts folders\\realstate\\gurgaon_properties_cleaned_v2.csv').drop_duplicates()
# Create the ProfileReport object
profile = ProfileReport(df)
# Generate the report
profile.to_file("report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       4 df = pd.read_csv('D:\\machine learning projecsts folders\\realstate\\gurgaon_properties_cleaned_v2.csv').drop_duplicates()
#       5 # Create the ProfileReport object
#
# ModuleNotFoundError: No module named 'ydata_profiling'
